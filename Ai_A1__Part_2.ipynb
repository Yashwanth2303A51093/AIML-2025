# %% [markdown]
# <a href="https://colab.research.google.com/github/Yashwanth2303A51093/AIML-2025/blob/main/Ai_A1__Part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#part 2
#1st Question
import numpy
import matplotlib.pyplot as plt
people = ["kiran", "arun", "vijay"," varun"]
age =[25, 30, 35, 40]
height =[145, 151, 165, 173]
weight=[45, 55, 65, 75]
#3nd Question
plt.scatter(people,age)
plt.xlabel("People")
plt.ylabel("age")
plt.title("People and there Age")
plt.show()
plt.scatter(people,height)
plt.xlabel("People")
plt.ylabel("Height")
plt.title("People and there Height")
plt.show()
plt.scatter(people,weight)
plt.xlabel("People")
plt.ylabel("Weight")
plt.title("People and there Weight")
plt.show()
plt.scatter(age,height)
plt.xlabel("Age")
plt.ylabel("Height")
plt.title("Age and there Height")
plt.show()
plt.scatter(age,weight)
plt.xlabel("Age")
plt.ylabel("Weight")
plt.title("Age and there Weight")
plt.show()
plt.scatter(height,weight)
plt.xlabel("Height")
plt.ylabel("Weight")
plt.title("Age and there Height")
plt.show()
#4th Question
plt.bar(people,age)
plt.xlabel("People")
plt.ylabel("Age")
plt.title("People and there Age")
plt.show()
plt.bar(people,height)
plt.xlabel("People")
plt.ylabel("Height")
plt.title("People and there Height")
plt.show()
plt.bar(people,weight)
plt.xlabel("People")
plt.ylabel("Height")
plt.title("People and there Weight")
plt.show()
plt.bar(age,height)
plt.xlabel("Age")
plt.ylabel("Height")
plt.title("Age and there Height")
plt.show()
plt.bar(age,weight)
plt.xlabel("Age")
plt.ylabel("Weight")
plt.title("Age and there Weight")
plt.show()
plt.bar(height,weight)
plt.xlabel("Height")
plt.ylabel("Weight")
plt.title("Height and there Weight")
plt.show()
#5th question
plt.hist(age)
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Histogram of Age")
plt.show()
plt.hist(height)
plt.xlabel("Height")
plt.ylabel("Frequency")
plt.title("Histogram of Height")
plt.show()
plt.hist(weight)
plt.xlabel("Weight")
plt.ylabel("Frequency")
plt.title("Histogram of Weight")
plt.show()
